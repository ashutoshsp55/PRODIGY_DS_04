# %% [markdown]
# # Task 4 Prodigy Infotech

# %% [markdown]
# ### Importing Datasets

# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\lenovo\Desktop\data_science_internship\twitter_training.csv')

# %%
data.head()
# Out:
#    2401  Borderlands  Positive  \
# 0  2401  Borderlands  Positive
# 1  2401  Borderlands  Positive
# 2  2401  Borderlands  Positive
# 3  2401  Borderlands  Positive
# 4  2401  Borderlands  Positive
#
#   im getting on borderlands and i will murder you all ,
# 0  I am coming to the borders and I will kill you...
# 1  im getting on borderlands and i will kill you ...
# 2  im coming on borderlands and i will murder you...
# 3  im getting on borderlands 2 and i will murder ...
# 4  im getting into borderlands and i can murder y...

# %%
data.columns
# Out:
# Index(['2401', 'Borderlands', 'Positive',
#        'im getting on borderlands and i will murder you all ,'],
#       dtype='object')

# %%
data2 = pd.read_csv(r'C:\Users\lenovo\Desktop\data_science_internship\twitter_validation.csv')
data2.head()
# Out:
#    3364   Facebook Irrelevant  \
# 0   352     Amazon    Neutral
# 1  8312  Microsoft   Negative
# 2  4371      CS-GO   Negative
# 3  4433     Google    Neutral
# 4  6273       FIFA   Negative
#
#   I mentioned on Facebook that I was struggling for motivation to go for a run the other day, which has been translated by Tom’s great auntie as ‘Hayley can’t get out of bed’ and told to his grandma, who now thinks I’m a lazy, terrible person 🤣
# 0  BBC News - Amazon boss Jeff Bezos rejects clai...
# 1  @Microsoft Why do I pay for WORD when it funct...
# 2  CSGO matchmaking is so full of closet hacking,...
# 3  Now the President is slapping Americans in the...
# 4  Hi @EAHelp I’ve had Madeleine McCann in my cel...

# %%
data.count()
# Out:
# 2401                                                     74681
# Borderlands                                              74681
# Positive                                                 74681
# im getting on borderlands and i will murder you all ,    73995
# dtype: int64

# %%
data2.count()
# Out:
# 3364                                                                                                                                                                                                                                                  999
# Facebook                                                                                                                                                                                                                                              999
# Irrelevant                                                                                                                                                                                                                                            999
# ...

# %%
data.tail(3)
# Out:
#        2401 Borderlands  Positive  \
# 74678  9200      Nvidia  Positive
# 74679  9200      Nvidia  Positive
# 74680  9200      Nvidia  Positive
#
#       im getting on borderlands and i will murder you all ,
# 74678  Just realized the windows partition of my Mac ...
# 74679  Just realized between the windows partition of...
# 74680  Just like the windows partition of my Mac is l...

# %%
#data2.head(1)
data2.tail(1)
# Out:
#      3364         Facebook Irrelevant  \
# 998  6960  johnson&johnson    Neutral
#
#     I mentioned on Facebook that I was struggling for motivation to go for a run the other day, which has been translated by Tom’s great auntie as ‘Hayley can’t get out of bed’ and told to his grandma, who now thinks I’m a lazy, terrible person 🤣
# 998  Johnson & Johnson to stop selling talc baby po...

# %%
data.columns = ['id','brand','sentiment','text']

# %%
data.columns
# Out:
# Index(['id', 'brand', 'sentiment', 'text'], dtype='object')

# %% [markdown]
# ### Performing Data Cleaning And EDA

# %%
data.head()
# Out:
#      id        brand sentiment  \
# 0  2401  Borderlands  Positive
# 1  2401  Borderlands  Positive
# 2  2401  Borderlands  Positive
# 3  2401  Borderlands  Positive
# 4  2401  Borderlands  Positive
#
#                                                 text
# 0  I am coming to the borders and I will kill you...
# 1  im getting on borderlands and i will kill you ...
# 2  im coming on borderlands and i will murder you...
# 3  im getting on borderlands 2 and i will murder ...
# 4  im getting into borderlands and i can murder y...

# %%
data.brand.unique()
# Out:
# array(['Borderlands', 'CallOfDutyBlackopsColdWar', 'Amazon', 'Overwatch',
#        'Xbox(Xseries)', 'NBA2K', 'Dota2', 'PlayStation5(PS5)',
#        'WorldOfCraft', 'CS-GO', 'Google', 'AssassinsCreed', 'ApexLegends',
#        'LeagueOfLegends', 'Fortnite', 'Microsoft', 'Hearthstone',
#        'Battlefield', 'PlayerUnknownsBattlegrounds(PUBG)', 'Verizon',
#        'HomeDepot', 'FIFA', 'RedDeadRedemption(RDR)', 'CallOfDuty',
#        'TomClancysRainbowSix', 'Facebook', 'GrandTheftAuto(GTA)',
#        'MaddenNFL', 'johnson&johnson', 'Cyberpunk2077',
#        'TomClancysGhostRecon', 'Nvidia'], dtype=object)

# %%
data2.head()
# Out:
#    3364   Facebook Irrelevant  \
# 0   352     Amazon    Neutral
# 1  8312  Microsoft   Negative
# 2  4371      CS-GO   Negative
# 3  4433     Google    Neutral
# 4  6273       FIFA   Negative
#
#   I mentioned on Facebook that I was struggling for motivation to go for a run the other day, which has been translated by Tom’s great auntie as ‘Hayley can’t get out of bed’ and told to his grandma, who now thinks I’m a lazy, terrible person 🤣
# 0  BBC News - Amazon boss Jeff Bezos rejects clai...
# 1  @Microsoft Why do I pay for WORD when it funct...
# 2  CSGO matchmaking is so full of closet hacking,...
# 3  Now the President is slapping Americans in the...
# 4  Hi @EAHelp I’ve had Madeleine McCann in my cel...

# %%
validation = data2
validation.head(1)
# Out:
#    3364 Facebook Irrelevant  \
# 0   352   Amazon    Neutral
#
#   I mentioned on Facebook that I was struggling for motivation to go for a run the other day, which has been translated by Tom’s great auntie as ‘Hayley can’t get out of bed’ and told to his grandma, who now thinks I’m a lazy, terrible person 🤣
# 0  BBC News - Amazon boss Jeff Bezos rejects clai...

# %%
validation.columns = ['id','brand','sentiment','text']
validation.columns
# Out:
# Index(['id', 'brand', 'sentiment', 'text'], dtype='object')

# %%
data.head()
# Out:
#      id        brand sentiment  \
# 0  2401  Borderlands  Positive
# 1  2401  Borderlands  Positive
# 2  2401  Borderlands  Positive
# 3  2401  Borderlands  Positive
# 4  2401  Borderlands  Positive
#
#                                                 text
# 0  I am coming to the borders and I will kill you...
# 1  im getting on borderlands and i will kill you ...
# 2  im coming on borderlands and i will murder you...
# 3  im getting on borderlands 2 and i will murder ...
# 4  im getting into borderlands and i can murder y...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74681 entries, 0 to 74680
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         74681 non-null  int64
#  1   brand      74681 non-null  object
#  2   sentiment  74681 non-null  object
#  3   text       73995 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 2.3+ MB

# %%
data.describe()
# Out:
#                  id
# count  74681.000000
# mean    6432.640149
# std     3740.423819
# min        1.000000
# 25%     3195.000000
# 50%     6422.000000
# 75%     9601.000000
# max    13200.000000

# %%
data.isnull().sum()
# Out:
# id             0
# brand          0
# sentiment      0
# text         686
# dtype: int64

# %%
data.dropna(inplace=True)
data.isnull().sum()
# Out:
# id           0
# brand        0
# sentiment    0
# text         0
# dtype: int64

# %%
data.count()
# Out:
# id           73995
# brand        73995
# sentiment    73995
# text         73995
# dtype: int64

# %%
data.text[20]
# Out:
# 'that was the first borderlands session in a long time where i actually enjoyed a really satisfying combat experience. i got some rather good kills'

# %%
data[data.sentiment =='Neutral'].count()
# Out:
# id           18108
# brand        18108
# sentiment    18108
# text         18108
# dtype: int64

# %%
twitter = pd.concat([data,validation],ignore_index=True)
twitter.head()
# Out:
#      id        brand sentiment  \
# 0  2401  Borderlands  Positive
# 1  2401  Borderlands  Positive
# 2  2401  Borderlands  Positive
# 3  2401  Borderlands  Positive
# 4  2401  Borderlands  Positive
#
#                                                 text
# 0  I am coming to the borders and I will kill you...
# 1  im getting on borderlands and i will kill you ...
# 2  im coming on borderlands and i will murder you...
# 3  im getting on borderlands 2 and i will murder ...
# 4  im getting into borderlands and i can murder y...

# %%
twitter.count()
# Out:
# id           74994
# brand        74994
# sentiment    74994
# text         74994
# dtype: int64

# %%
twitter.tail(1)
# Out:
#          id            brand sentiment  \
# 74993  6960  johnson&johnson   Neutral
#
#                                                     text
# 74993  Johnson & Johnson to stop selling talc baby po...

# %%
from sklearn.model_selection import train_test_split

# %%
X = twitter['text']
y = twitter['sentiment']
X
y
# Out:
# 0          Positive
# 1          Positive
# 2          Positive
# 3          Positive
# 4          Positive
#             ...
# 74989    Irrelevant
# 74990    Irrelevant
# 74991      Positive
# 74992      Positive
# 74993       Neutral
# Name: sentiment, Length: 74994, dtype: object

# %% [markdown]
# ### Model Prediction

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(max_features=100,ngram_range=(1,2))
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)
X_train_vect = vectorizer.fit_transform(X_train)
X_test_vect = vectorizer.transform(X_test)

# %%
from sklearn.svm import LinearSVC

# %%
clf = LinearSVC()

# %%
model  = clf.fit(X_train_vect, y_train)

# %%
y_pred = clf.predict(X_test_vect)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#   Irrelevant       0.40      0.12      0.18      3903
#     Negative       0.48      0.58      0.53      6844
#      Neutral       0.50      0.41      0.45      5523
#     Positive       0.42      0.58      0.49      6229
#
#     accuracy                           0.46     22499
#    macro avg       0.45      0.42      0.41     22499
# weighted avg       0.45      0.46      0.44     22499

# %%
print(clf.score)
# Out:
# <bound method ClassifierMixin.score of LinearSVC()>

# %%
print(model.score)
# Out:
# <bound method ClassifierMixin.score of LinearSVC()>

# %%
sentiment_dist = data['sentiment'].value_counts()

# %%
sentiment_dist
# Out:
# Negative      22358
# Positive      20654
# Neutral       18108
# Irrelevant    12875
# Name: sentiment, dtype: int64

# %% [markdown]
# ### Data Visualisation

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(5,4))
plt.pie(sentiment_dist,labels=sentiment_dist,autopct='%1.1f%%',startangle=140)
plt.axis('equal')
plt.title('Sentiment Distribution')
plt.show()

# %%
plt.figure(figsize=(5,4))
brand_sentiment = data.groupby(['brand', 'sentiment']).size().unstack(fill_value=0).head(10)
brand_sentiment.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Brand-specific Sentiment Analysis')
plt.xlabel('Brand')
plt.ylabel('Number of Tweets')
plt.legend(title='Sentiment')
plt.xticks(rotation=45)
plt.show()

# %%
from nltk.tokenize import word_tokenize
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from collections import Counter
from wordcloud import WordCloud
import nltk

nltk.download('punkt')
nltk.download('vader_lexicon')

data['Tokens'] = data['text'].apply(word_tokenize)

words = [word for tokens in data['Tokens'] for word in tokens]
word_freq = Counter(words)
top_words = word_freq.most_common(20) 

sid = SentimentIntensityAnalyzer()
data['sentiment'] = data['text'].apply(lambda x: sid.polarity_scores(x)['compound'])

wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(dict(top_words))
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Top 20 Most Frequent Words')
plt.axis('off')
plt.show()

plt.figure(figsize=(8, 6))
plt.hist(data['sentiment'], bins=30, color='skyblue', edgecolor='black')
plt.title('Sentiment Distribution')
plt.xlabel('Compound Sentiment Score')
plt.ylabel('Frequency')
plt.show()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
sentiment_by_category = data.groupby('brand')['sentiment'].mean().head(10)
plt.figure(figsize=(10, 6))
sentiment_by_category.plot(kind='bar', color='skyblue')
plt.title('Average Sentiment by Category')
plt.xlabel('Category')
plt.ylabel('Average Sentiment Score')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
correlation_matrix = data.corr()
plt.figure(figsize=(6, 4))
plt.imshow(correlation_matrix, cmap='coolwarm', interpolation='nearest')
plt.title('Correlation between External Factors and Sentiment')
plt.colorbar()
plt.xticks(range(len(correlation_matrix.columns)), correlation_matrix.columns, rotation=45)
plt.yticks(range(len(correlation_matrix.columns)), correlation_matrix.columns)
plt.show()
